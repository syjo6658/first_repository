# %%
import requests
import time
from selenium import webdriver
from bs4 import BeautifulSoup

# 웹드라이버 구동
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36')
driver = webdriver.Chrome(options=options)
soup = BeautifulSoup(driver.page_source, "lxml")
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"}


# 네이버 도서 페이지
#driver.get("https://search.shopping.naver.com/book/search/category?bookTabType=NEW_BOOK&catId=50005542&pageIndex=1&pageSize=40")

interval = 2
prev_height = driver.execute_script("return document.body.scrollHeight")

while True :
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    
    time.sleep(interval)
    
    curr_height = driver.execute_script("return document.body.scrollHeight")

    if curr_height == prev_height :
        break
        
    prev_height = curr_height


for page in range(1, 6):
    url = 'https://search.shopping.naver.com/book/search/category?bookTabType=NEW_BOOK&catId=50005542&pageIndex={}&pageSize=40'.format(page)
    res = requests.get(url, headers=headers) 
    res.raise_for_status()

    books = soup.find_all("li", {"class" : "bookListItem_item_book__1yCey"})
    
    for book in books :
        
        
        for title in titles :

            title = driver.find_elements_by_class_name("bookListItem_text__bglOw")
            title = title.text
            print(title)

# %%
import requests
from bs4 import BeautifulSoup

headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"}

for page in range(1, 6):
    url = 'https://search.shopping.naver.com/book/search/category?bookTabType=NEW_BOOK&catId=50005542&pageIndex={}&pageSize=40'.format(page)
    res = requests.get(url, headers) 
    res.raise_for_status()

    soup = BeautifulSoup(res.text, 'lxml')
    titles = soup.find_all('span', {'class' : 'bookListItem_text__bglOw'})

    for title in titles:
        print(title.get_text())

# %%
import requests
import time
from selenium import webdriver
from bs4 import BeautifulSoup

# 웹드라이버 구동
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36')
driver = webdriver.Chrome(options=options)
soup = BeautifulSoup(driver.page_source, "lxml")
headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"}


# 네이버 도서 페이지
#driver.get("https://search.shopping.naver.com/book/search/category?bookTabType=NEW_BOOK&catId=50005542&pageIndex=1&pageSize=40")

interval = 2
prev_height = driver.execute_script("return document.body.scrollHeight")

while True :
    
    for page in range(1, 6):
        driver.get("https://search.shopping.naver.com/book/search/category?bookTabType=NEW_BOOK&catId=50005542&pageIndex=1&pageSize=40".format(page))
        soup = BeautifulSoup(driver.page_source, "lxml")
        books = soup.find_all("li", attrs={"class" : "bookListItem_item_book__1yCey"})

        #for book in books :

        titles = []    
        for title in titles :

            title = driver.find_elements_by_class_name("bookListItem_text__bglOw")
            title = title.text
            print(title)
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    
    time.sleep(interval)
    
    curr_height = driver.execute_script("return document.body.scrollHeight")

    if curr_height == prev_height :
        break
        
    prev_height = curr_height

# %%
import time
from selenium import webdriver
import requests
from bs4 import BeautifulSoup

options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36')
driver = webdriver.Chrome(options=options)

headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"}

interval = 2
prev_height = driver.execute_script("return document.body.scrollHeight")

for page in range(1, 6):

    print(f"{page} 페이지")
    
    driver.get("https://search.shopping.naver.com/book/search/category?bookTabType=NEW_BOOK&catId=50005542&pageIndex={}&pageSize=40".format(page))

    while True :
        
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    
        time.sleep(interval)
    
        curr_height = driver.execute_script("return document.body.scrollHeight")

        if curr_height == prev_height :

            break   
        
        prev_height = curr_height
        
    soup = BeautifulSoup(driver.page_source, 'lxml')
    
    books = soup.find_all("div", attrs={"class" : "bookListItem_item_inner__Fp7hN"})
    #books = soup.select('li.bookListItem_item_book__1yCey')
    print(len(books))
    
    for book in books :
        
        title = book.find('span', attrs={'class' : 'bookListItem_text__bglOw'}).get_text()
        print("제목 : " + title)
        
        author = book.find('span', attrs={'class' : 'bookListItem_author__fdjcn'}).span.next_sibling
        print("작가 : " + author)
        
        genre = book.find('div', attrs={'class' : 'bookListItem_feature__txTlp'})
        if genre != None :
            if len(genre.get_text().split()) == 3 :
                genre_rank = genre.get_text().split()[2].strip("위")
                genre_rank = int(genre_rank)
                genre = genre.get_text().split()[0] + " " + genre.get_text().split()[1]
                print(genre)
                print(genre_rank)
            
            else :
                genre, genre_rank = genre.get_text().split()
                genre_rank = genre_rank.strip("위")
                genre_rank = int(genre_rank)
                print(genre)
                print(genre_rank)
        
        publisher = book.find('span', attrs={'class' : 'bookListItem_detail_item___YTUp'}).span.next_sibling
        print("출판 : " + publisher)
        
        publication_date = book.find('span', attrs={'class' : 'bookListItem_detail_item___YTUp bookListItem_date__LWyh_'}).get_text()
        print("출판일 : " + publication_date)
        
        price = book.find_all('span', attrs={'class' : 'bookPrice_price__zr5dh'})
        
        if len(price) == 2 :
            book_price = price[0].get_text().strip("최저 원").replace(',', '')
            book_price = int(book_price)
            ebook_price = price[1].get_text().strip("구매 대여 원").replace(',', '')
            ebook_price = int(ebook_price)
            print("가격 :", book_price)
            print("ebook 가격 :", ebook_price)
            
        else :
            book_price = price[0].get_text().strip("최저 원").replace(',', '')
            print("가격 :", book_price)
                        
        
        
driver.quit()

# %%
import time
from selenium import webdriver
import requests
from bs4 import BeautifulSoup

options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36')
driver = webdriver.Chrome(options=options)

headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"}

interval = 2
prev_height = driver.execute_script("return document.body.scrollHeight")

driver.get("https://search.shopping.naver.com/book/search/category?bookTabType=BEST_SELLER&catId=50005542&pageIndex=1&pageSize=40")

while True :
        
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    
    time.sleep(interval)
    
    curr_height = driver.execute_script("return document.body.scrollHeight")

    if curr_height == prev_height :

        break   
        
    prev_height = curr_height
        
soup = BeautifulSoup(driver.page_source, 'lxml')
    
books = soup.find_all("div", attrs={"class" : "bookListItem_item_inner__Fp7hN"})
#books = soup.select('li.bookListItem_item_book__1yCey')
print(len(books))
    
for book in books :
        
    title = book.find('span', attrs={'class' : 'bookListItem_text__bglOw'}).span.next_sibling.get_text()
    rank = book.find('span', attrs={'class' : 'bookListItem_rank__x1oKQ'}).get_text().strip("위")
    rank = int(rank)
    print("순위 :", rank)
    print("제목 : " + title)
    
    author = book.find('span', attrs={'class' : 'bookListItem_author__fdjcn'}).span.next_sibling
    print("작가 : " + author)
        
    publisher = book.find('span', attrs={'class' : 'bookListItem_detail_item___YTUp'}).span.next_sibling
    print("출판 : " + publisher)
        
    publication_date = book.find('span', attrs={'class' : 'bookListItem_detail_item___YTUp bookListItem_date__LWyh_'})
    if publication_date != None :
        publication_date = book.find('span', attrs={'class' : 'bookListItem_detail_item___YTUp bookListItem_date__LWyh_'}).get_text()
        print("출판일 : " + publication_date)
        
    price = book.find_all('span', attrs={'class' : 'bookPrice_price__zr5dh'})
        
    if len(price) == 2 :
        book_price = price[0].get_text().strip("최저 원").replace(',', '')
        book_price = int(book_price)
        ebook_price = price[1].get_text().strip("구매 대여 원").replace(',', '')
        ebook_price = int(ebook_price)
        print("가격 :", book_price)
        print("ebook 가격 :", ebook_price)
            
    else :
        book_price = price[0].get_text().strip("최저 원").replace(',', '')
        print("가격 :", book_price)
                        
    print("-" * 100)
        
driver.quit()

# %%
import pymysql

db = pymysql.connect(host='localhost', port=3306, user='root', passwd='1234', db='mywork', charset='utf8')

# %%
db

# %%
project = db.cursor()

project

# %%
sql = """
    create table newbooks (
        book_id INT,
        title varchar(200) not null,
        author varchar(30) not null,
        genre varchar(30),
        genre_rank int,
        publisher varchar(30),
        publication_date datetime,
        price int,
        ebook_price int,
        primary key(book_id)
    );
"""
project.execute(sql)
# Out:
# 0

# %%
sql = """
    create table bestsellers (
        bookrank int,
        title varchar(200) not null,
        author varchar(30) not null,
        publisher varchar(30),
        publication_date datetime,
        price int,
        ebook_price int,
        primary key(bookrank)
    );
"""
project.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Input In [10], in <cell line: 13>()
#       1 sql = """
#       2     create table bestsellers (
#       3         bookrank int,
#    (...)
#      11     );
#      12 """
# ---> 13 project.execute(sql)
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# File ~\anaconda3\lib\site-packages\pymysql\connections.py:547, in Connection.query(self, sql, unbuffered)
# ...

# %%
db.commit()

# %%
# 신간 스크래핑 + db 입력

import time
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import pymysql

# db 부분
db = pymysql.connect(host='localhost', port=3306, user='root', passwd='1234', db='mywork', charset='utf8')
project = db.cursor()

options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36')
driver = webdriver.Chrome(options=options)

headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"}

interval = 2
prev_height = driver.execute_script("return document.body.scrollHeight")
book_id = 1

for page in range(1, 6):

    print(f"{page} 페이지")
    
    driver.get("https://search.shopping.naver.com/book/search/category?bookTabType=NEW_BOOK&catId=50005542&pageIndex={}&pageSize=40".format(page))

    while True :
        
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    
        time.sleep(interval)
    
        curr_height = driver.execute_script("return document.body.scrollHeight")

        if curr_height == prev_height :

            break   
        
        prev_height = curr_height
        
    soup = BeautifulSoup(driver.page_source, 'lxml')
    
    books = soup.find_all("div", attrs={"class" : "bookListItem_item_inner__Fp7hN"})
    #books = soup.select('li.bookListItem_item_book__1yCey')
    print(len(books))
    
    for book in books :
        
        print(book_id)
        title = book.find('span', attrs={'class' : 'bookListItem_text__bglOw'}).get_text()
        print("제목 : " + title)
        
        author = book.find('span', attrs={'class' : 'bookListItem_author__fdjcn'}).span.next_sibling
        print("작가 : " + author)
        
        genre = book.find('div', attrs={'class' : 'bookListItem_feature__txTlp'})
        if genre != None :
            if len(genre.get_text().split()) == 3 :
                genre_rank = genre.get_text().split()[2].strip("위")
                genre_rank = int(genre_rank)
                genre = genre.get_text().split()[0] + " " + genre.get_text().split()[1]
                print(genre)
                print(genre_rank)
            
            else :
                genre, genre_rank = genre.get_text().split()
                genre_rank = genre_rank.strip("위")
                genre_rank = int(genre_rank)
                print(genre)
                print(genre_rank)
        
        publisher = book.find('span', attrs={'class' : 'bookListItem_detail_item___YTUp'}).span.next_sibling
        print("출판 : " + publisher)
        
        publication_date = book.find('span', attrs={'class' : 'bookListItem_detail_item___YTUp bookListItem_date__LWyh_'}).get_text()
        print("출판일 : " + publication_date)
        
        price = book.find_all('span', attrs={'class' : 'bookPrice_price__zr5dh'})
        
        if len(price) == 2 :
            book_price = price[0].get_text().strip("최저 원").replace(',', '')
            book_price = int(book_price)
            ebook_price = price[1].get_text().strip("구매 대여 원").replace(',', '')
            ebook_price = int(ebook_price)
            print("가격 :", book_price)
            print("ebook 가격 :", ebook_price)
            
        else :
            book_price = price[0].get_text().strip("최저 원").replace(',', '')
            print("가격 :", book_price)

        # sql db 입력
        sql = """
            INSERT INTO NEWBOOKS VALUES (
            {}, "{}", "{}", "{}", {}, "{}", str_to_date("{}", '%Y.%m.%d.'), {}, {});
              """.format(book_id, title, author, genre, genre_rank, publisher, publication_date, book_price, ebook_price)
        project.execute(sql)
        db.commit()
        
        book_id += 1

db.close() 
driver.quit()
# Out:
# 1 페이지
# 40
# 1
# 제목 : 때로는 행복 대신 불행을 택하기도 한다 (김진명 에세이)
# 작가 : 김진명
# 시/에세이
# 14
# 출판 : 이타북스
# 출판일 : 2022.07.28.
# 가격 : 14400
# ebook 가격 : 10080
#
#             INSERT INTO NEWBOOKS VALUES (
#             1, "때로는 행복 대신 불행을 택하기도 한다 (김진명 에세이)", "김진명", "시/에세이", 14, "이타북스", str_to_date("2022.07.28.", '%Y.%m.%d.'), 14400, 10080);
#
# 2
# 제목 : 나라면 나와 결혼할까? (매일 조금씩 나아지는 나를 응원해)
# 작가 : 뤼후이
# 시/에세이
# 3
# 출판 : 미디어숲
# 출판일 : 2022.08.10.
# 가격 : 15120
# ebook 가격 : 10590
#
#             INSERT INTO NEWBOOKS VALUES (
#             2, "나라면 나와 결혼할까? (매일 조금씩 나아지는 나를 응원해)", "뤼후이", "시/에세이", 3, "미디어숲", str_to_date("2022.08.10.", '%Y.%m.%d.'), 15120, 10590);
#
# 3
# 제목 : 반려공구 (공구와 함께 만든 자유롭고 단단한 일상)
# 작가 : 모호연
# 시/에세이
# 102
# 출판 : 라이프앤페이지
# 출판일 : 2022.08.16.
# 가격 : 14400
# ebook 가격 : 10080
#
#             INSERT INTO NEWBOOKS VALUES (
#             3, "반려공구 (공구와 함께 만든 자유롭고 단단한 일상)", "모호연", "시/에세이", 102, "라이프앤페이지", str_to_date("2022.08.16.", '%Y.%m.%d.'), 14400, 10080);
#
# 4
# 제목 : 묘사하는 마음 (김혜리 영화 산문집)
# ...

# %%
# 베스트셀러 스크래핑 + db 입력

import time
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import pymysql

# db 부분
db = pymysql.connect(host='localhost', port=3306, user='root', passwd='1234', db='mywork', charset='utf8')
project = db.cursor()

options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36')
driver = webdriver.Chrome(options=options)

headers = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"}

interval = 2
prev_height = driver.execute_script("return document.body.scrollHeight")

driver.get("https://search.shopping.naver.com/book/search/category?bookTabType=BEST_SELLER&catId=50005542&pageIndex=1&pageSize=40")

while True :
        
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    
    time.sleep(interval)
    
    curr_height = driver.execute_script("return document.body.scrollHeight")

    if curr_height == prev_height :

        break   
        
    prev_height = curr_height
        
soup = BeautifulSoup(driver.page_source, 'lxml')
    
books = soup.find_all("div", attrs={"class" : "bookListItem_item_inner__Fp7hN"})
    
for book in books :
        
    title = book.find('span', attrs={'class' : 'bookListItem_text__bglOw'}).span.next_sibling.get_text()
    bookrank = book.find('span', attrs={'class' : 'bookListItem_rank__x1oKQ'}).get_text().strip("위")
    bookrank = int(bookrank)
    print("순위 :", bookrank)
    print("제목 : " + title)
    
    author = book.find('span', attrs={'class' : 'bookListItem_author__fdjcn'}).span.next_sibling
    print("작가 : " + author)
        
    publisher = book.find('span', attrs={'class' : 'bookListItem_detail_item___YTUp'}).span.next_sibling
    print("출판 : " + publisher)
        
    publication_date = book.find('span', attrs={'class' : 'bookListItem_detail_item___YTUp bookListItem_date__LWyh_'})
    if publication_date != None :
        publication_date = book.find('span', attrs={'class' : 'bookListItem_detail_item___YTUp bookListItem_date__LWyh_'}).get_text()
        print("출판일 : " + publication_date)
        
    else :
        publication_date = "2022.08.18."
        
    price = book.find_all('span', attrs={'class' : 'bookPrice_price__zr5dh'})
        
    if len(price) == 2 :
        book_price = price[0].get_text().strip("최저 원").replace(',', '')
        book_price = int(book_price)
        ebook_price = price[1].get_text().strip("구매 대여 원").replace(',', '')
        ebook_price = int(ebook_price)
        print("가격 :", book_price)
        print("ebook 가격 :", ebook_price)
            
    else :
        book_price = price[0].get_text().strip("최저 원").replace(',', '')
        print("가격 :", book_price)
        
    # sql db 입력
    sql = """
        INSERT INTO BESTSELLERS VALUES (
        {}, "{}", "{}", "{}", str_to_date("{}", '%Y.%m.%d.'), {}, {});
          """.format(bookrank, title, author, publisher, publication_date, book_price, ebook_price)
    project.execute(sql)
    db.commit()
        
driver.quit()
# Out:
# 순위 : 1
# 제목 : 하얼빈
# 작가 : 김훈
# 출판 : 문학동네
# 출판일 : 2022.08.03.
# 가격 : 14400
# ebook 가격 : 10080
# 순위 : 2
# 제목 : 파친코 2
# 작가 : 이민진
# 출판 : 인플루엔셜(주)
# 출판일 : 2022.08.25.
# 가격 : 14220
# 순위 : 3
# 제목 : 역행자
# 작가 : 자청
# 출판 : 웅진지식하우스
# 출판일 : 2022.05.30.
# 가격 : 15750
# ebook 가격 : 11070
# 순위 : 4
# 제목 : 불편한 편의점 2
# 작가 : 김호연
# 출판 : 나무옆의자
# 출판일 : 2022.08.10.
# 가격 : 12600
# 순위 : 5
# 제목 : 헤어질 결심 각본
# 작가 : 정서경, 박찬욱
# 출판 : 을유문화사
# 출판일 : 2022.08.05.
# 가격 : 13500
# ebook 가격 : 9450
# 순위 : 6
# 제목 : 계속 가보겠습니다
# 작가 : 임은정
# 출판 : 메디치미디어
# 출판일 : 2022.07.22.
# 가격 : 15390
# ebook 가격 : 11340
# 순위 : 7
# 제목 : 파친코 1
# 작가 : 이민진
# 출판 : 인플루엔셜
# 출판일 : 2022.08.05.
# 가격 : 14220
# 순위 : 8
# 제목 : 불편한 편의점
# 작가 : 김호연
# 출판 : 나무옆의자
# 출판일 : 2021.04.20.
# 가격 : 12600
# ebook 가격 : 8820
# 순위 : 9
# 제목 : 이상한 변호사 우영우 1
# 작가 : 문지원
# 출판 : 김영사
# 가격 : 17820
# 순위 : 10
# 제목 : 당신이라는 기적
# 작가 : 정한경
# 출판 : 북로망스
# 출판일 : 2022.07.07.
# 가격 : 14400
# ebook 가격 : 10080
# 순위 : 11
# 제목 : 이상한 변호사 우영우 2
# 작가 : 문지원
# 출판 : 김영사
# 가격 : 17820
# 순위 : 12
# 제목 : 흔한남매 11
# ...
